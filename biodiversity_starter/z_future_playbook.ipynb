# %% [markdown]
# # Exploratory Data Analysis Playbook

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#

# %% [markdown]
# ## Load

# %%
df = pd.read_csv('FILENAME.csv')

# %% [markdown]
# ## Inspect
#
# 1. Col names
# 2. Data Type --> Int64, float64, categorical, object

# %%
df.head()
df.describe(include='all')
df.info()
df.shape()

# %% [markdown]
# ## Duplicates and Missing Values

# %%
print('Missing values per column:')
print(df.isnull().sum())

df.index.is_unique() # True for unique values, False for not
df.columns.is_unique() # same
df.column_name.duplicated() # --> returns array with boolean vals indicating if label is dup
df.loc[~df.index.duplicated(), :]

# even if it looks like dups it's a unique key for each label
df.groupby(['col1', 'col2'], observed=True)['col_for_operations'].sum().reset_index().copy()

# %% [markdown]
# ## Transform
# 1. Convert Column Names
# 2. Convert Data Types
# 3. Sort
# 4. Group
# 5. Merge
# 6. Pivot
# 7. Derived Columns

# %%
# Convert categorical columns to category dtype
categorical_cols = ['item1', 'item2', 'item3']

for col in categorical_cols:
    df[col] = df[col].astype('category')

numeric_cols = ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']

# Descriptive statistics for numeric columns
print('Numeric Data Summary:')
print(df[numeric_cols].describe())

# If any cleaning is necessary that might be useful for other creators, note that verifying data types is crucial to avoid errors later in the analysis.

# Splitting into features and target for prediction later
target = 'price'
features = ['area', 'bedrooms', 'bathrooms', 'stories', 'parking'] + categorical_cols

# %% [markdown]
# ## Validate
